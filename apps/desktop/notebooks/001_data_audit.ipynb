# %% [markdown]
# # 001 Data Audit
#
# Use this notebook to inspect raw market data before any feature engineering or backtesting.

# %%
from pathlib import Path

from stocker_core.config import load_research_config

candidates = [
    Path("configs/research.example.yaml"),
    Path("../../../configs/research.example.yaml"),
]
config_path = next(path for path in candidates if path.exists())
config = load_research_config(config_path)
config
