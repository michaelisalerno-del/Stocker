# %% [markdown]
# # 002 Baseline Research
#
# Use this notebook for simple benchmark and null-hypothesis checks before strategy work.

# %%
import pandas as pd

from stocker_research.baselines import ohlc_baseline_summary

sample = pd.DataFrame(
    {
        "open": [100.0, 101.0, 102.0],
        "high": [101.0, 103.0, 104.0],
        "low": [99.0, 100.0, 101.0],
        "close": [101.0, 102.0, 101.0],
        "volume": [1000, 1200, 900],
    }
)
ohlc_baseline_summary(sample)
